# %%
from statsmodels.iolib.summary2 import summary_col
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://github.com/SofiyaLyn/Thesis/raw/main/almostcleaned_data.csv'
cleaned_data = pd.read_csv(url)
cleaned_data.head()
# Out:
#    Year  Country Proceeds_Amount_+_Over_Sold_This_Market_(USD,_mln)  \
# 0  2009  Hungary                                               0.00
# 1  2010  Hungary                                             179.37
# 2  2011  Hungary                                               0.00
# 3  2012  Hungary                                               2.93
# 4  2013  Hungary                                               1.97
#
#    IPO_market_share New_Business  IPOs_Number_of_Issues  P/E_Ratio E/P_ratio  \
# 0              0.00        42046                      1    15.2913      0.07
# 1             64.03    44,269.00                      4    12.1724      0.08
# 2              0.00    52,217.00                      1    10.8504      0.09
# 3              1.05    32,311.00                      1    12.6385      0.08
# 4              0.70    28,207.00                      1    10.6615      0.09
#
#   Stock_Market_Index  Interest_rate_up_to_1_mln  ...  \
# 0          21,227.01                        NaN  ...
# 1          21,327.07                       9.40  ...
# 2          16,974.24                       9.30  ...
# 3          18,173.20                      10.46  ...
# 4          18,564.08                       8.79  ...
#
#    Aver_interest_rate_to_nonfinance Real_GDP_Growth_(%)  Nominal_GDP_($B)  \
# 0                           #DIV/0!               -3.49             52.02
# 1                              8.61                1.39             50.68
# 2                             8.495                2.36             57.68
# 3                              9.65                0.49             54.30
# 4                              8.09               -0.59             55.81
#
#    Population_(M)  Population_Growth_(%) GDP_Per_Capita_($)  \
# 0            7.47                 (0.67)           6,961.09
# 1            7.43                 (0.65)           6,825.90
# 2            7.38                 (0.62)           7,817.14
# 3            7.33                 (0.61)           7,403.74
# 4            7.29                 (0.60)           7,655.79
#
#   Real_Private_Consumption_Growth_(%)  Real_Government_Consumption_Growth_(%)  \
# 0                               -4.69                                    0.00
# 1                                1.54                                    6.13
# 2                                2.14                                    0.66
# 3                                2.92                                   -0.27
# 4                               -3.24                                    2.76
#
#    Real_Gross_Fixed_Investment_Growth_(%)  Industrial_Production_Growth_(%)
# 0                                  -15.95                            -20.18
# 1                                  -19.09                             14.13
# 2                                   -3.66                             17.22
# 3                                    2.00                              2.32
# 4                                   -0.42                             -0.98
#
# [5 rows x 21 columns]

# %%
cleaned_data['treated'] = cleaned_data['Country'].isin(["Hungary", "Poland", "Slovakia", "Czech Republic", "Slovenia", "Bulgaria", "Romania", "Estonia", "Latvia", "Lithuania"])
cleaned_data['treated'] = cleaned_data['treated'].astype(int)

cleaned_data['post_intervention'] = (cleaned_data['Year'] >= 2018).astype(int)
cleaned_data['treated_intervention'] = cleaned_data['treated'] * cleaned_data['post_intervention']

print(cleaned_data.columns)
# Out:
# Index(['Year', 'Country', 'Proceeds_Amount_+_Over_Sold_This_Market_(USD,_mln)',
#        'IPO_market_share', 'New_Business', 'IPOs_Number_of_Issues',
#        'P/E_Ratio', 'E/P_ratio', 'Stock_Market_Index',
#        'Interest_rate_up_to_1_mln', 'Interest_rate_over_€1M',
#        'Aver_interest_rate_to_nonfinance', 'Real_GDP_Growth_(%)',
#        'Nominal_GDP_($B)', 'Population_(M)', 'Population_Growth_(%)',
#        'GDP_Per_Capita_($)', 'Real_Private_Consumption_Growth_(%)',
#        'Real_Government_Consumption_Growth_(%)',
#        'Real_Gross_Fixed_Investment_Growth_(%)',
#        'Industrial_Production_Growth_(%)', 'treated', 'post_intervention',
#        'treated_intervention'],
#       dtype='object')

# %%
cleaned_data.columns = cleaned_data.columns.str.replace('(', '_').str.replace(')', '').str.replace('%', 'Percent').str.replace('$', 'Dollar')

# %%
print(cleaned_data.columns)
# Out:
# Index(['Year', 'Country', 'Proceeds_Amount_+_Over_Sold_This_Market__USD,_mln',
#        'IPO_market_share', 'New_Business', 'IPOs_Number_of_Issues',
#        'P/E_Ratio', 'E/P_ratio', 'Stock_Market_Index',
#        'Interest_rate_up_to_1_mln', 'Interest_rate_over_€1M',
#        'Aver_interest_rate_to_nonfinance', 'Real_GDP_Growth__Percent',
#        'Nominal_GDP__DollarB', 'Population__M', 'Population_Growth__Percent',
#        'GDP_Per_Capita__Dollar', 'Real_Private_Consumption_Growth__Percent',
#        'Real_Government_Consumption_Growth__Percent',
#        'Real_Gross_Fixed_Investment_Growth__Percent',
#        'Industrial_Production_Growth__Percent', 'treated', 'post_intervention',
#        'treated_intervention'],
#       dtype='object')

# %%
formula = 'Interest_rate_up_to_1_mln ~ treated + post_intervention + treated_intervention'
model = smf.ols(formula, data=cleaned_data).fit()

summary_table = summary_col([model], stars=True)

print(summary_table)
# Out:
# ==============================================
#                      Interest_rate_up_to_1_mln
# ----------------------------------------------
# Intercept            7.4523***
#                      (0.5976)
# treated              -1.1743*
#                      (0.6945)
# post_intervention    -1.9910**
#                      (0.8711)
# treated_intervention -0.9184
#                      (1.0732)
# R-squared            0.1654
# R-squared Adj.       0.1497
# ==============================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
with open('Interest Rate on Business Loans up to EUR 1 mln.html', 'w') as f:
    f.write(summary_table.as_html())
with open('/Users/sonetalyn/Desktop/Thesis/Interest Rate on Business Loans up to EUR 1 mln.html', 'w') as f:
    f.write(summary_table.as_html())

# %%
# Fit the model
model = smf.ols(formula, data=cleaned_data).fit()

# Generate predicted values
cleaned_data['predicted'] = model.predict(cleaned_data)

# Group the data by 'Year' and 'treated', and calculate the mean of 'predicted'
grouped_data = cleaned_data.groupby(['Year', 'treated'])['predicted'].mean().reset_index()

# Create the plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=grouped_data, x='Year', y='predicted', hue='treated', style='treated', markers=True, dashes=False)

# Adding labels and title
plt.title('Interest Rate on Business Loans up to EUR 1 mln (Predicted)')
plt.xlabel('Year')
plt.ylabel('Average Outcome')
plt.legend(title='Treatment Status', labels=['Control', 'Treated'])
plt.axvline(x=2018, color='red', linestyle='--')

# Save the plot
plt.savefig('/Users/sonetalyn/Desktop/Thesis/Interest_Rate_UP_predicted_plot.png')

# Show the plot
plt.show()

# %%
cleaned_data['intercept'] = 1
formula = """ Interest_rate_up_to_1_mln ~ treated + post_intervention + treated_intervention + GDP_Per_Capita__Dollar + Real_Private_Consumption_Growth__Percent + Real_Government_Consumption_Growth__Percent + Real_Gross_Fixed_Investment_Growth__Percent + Industrial_Production_Growth__Percent + intercept"""
cleaned_data['Population_Growth__Percent'] = pd.to_numeric(cleaned_data['Population_Growth__Percent'], errors='coerce')
cleaned_data['GDP_Per_Capita__Dollar'] = cleaned_data['GDP_Per_Capita__Dollar'].astype(str).str.replace(',', '').astype(float)
model = smf.ols(formula, data=cleaned_data).fit()
summary_table = summary_col([model], stars=True)

# Print the summary table
print(summary_table)

# Save the summary table to an HTML file
with open('/Users/sonetalyn/Desktop/Thesis/Controlled Interest Rate up to 1 mln EUR.html', 'w') as f:
    f.write(summary_table.as_html())
# Out:
# =====================================================================
#                                             Interest_rate_up_to_1_mln
# ---------------------------------------------------------------------
# Intercept                                   5.1717***
#                                             (0.2966)
# treated                                     -0.4370
#                                             (0.5746)
# post_intervention                           -1.6885**
#                                             (0.6835)
# treated_intervention                        0.6615
#                                             (0.8614)
# GDP_Per_Capita__Dollar                      -0.0003***
#                                             (0.0000)
# Real_Private_Consumption_Growth__Percent    -0.0922
#                                             (0.0575)
# Real_Government_Consumption_Growth__Percent -0.1535**
#                                             (0.0688)
# Real_Gross_Fixed_Investment_Growth__Percent -0.0700***
#                                             (0.0213)
# Industrial_Production_Growth__Percent       0.0736**
#                                             (0.0312)
# intercept                                   5.1717***
#                                             (0.2966)
# R-squared                                   0.4796
# R-squared Adj.                              0.4526
# =====================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
# Fit the model
model = smf.ols(formula, data=cleaned_data).fit()

# Generate predicted values
cleaned_data['predicted'] = model.predict(cleaned_data)

# Group the data by 'Year' and 'treated', and calculate the mean of 'predicted'
grouped_data = cleaned_data.groupby(['Year', 'treated'])['predicted'].mean().reset_index()

# Create the plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=grouped_data, x='Year', y='predicted', hue='treated', style='treated', markers=True, dashes=False)

# Adding labels and title
plt.title('Interest Rate on Business Loans up to EUR 1 mln (Predicted)')
plt.xlabel('Year')
plt.ylabel('Average Outcome')
plt.legend(title='Treatment Status', labels=['Control', 'Treated'])
plt.axvline(x=2018, color='red', linestyle='--')

# Save the plot
plt.savefig('/Users/sonetalyn/Desktop/Thesis/Interest_Rate_UP_predicted_plot.png')

# Show the plot
plt.show()

# %% [markdown]
# ## Fixed Effects as Country and Year

# %%
formula = 'Interest_rate_up_to_1_mln ~ treated + post_intervention + treated_intervention + C(Year) + C(Country)'
model = smf.ols(formula, data=cleaned_data).fit()
print(model.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Interest_rate_up_to_1_mln   R-squared:                       0.812
# Model:                                   OLS   Adj. R-squared:                  0.774
# Method:                        Least Squares   F-statistic:                     21.69
# Date:                       Mon, 20 May 2024   Prob (F-statistic):           6.06e-37
# Time:                               15:48:25   Log-Likelihood:                -294.48
# No. Observations:                        164   AIC:                             645.0
# Df Residuals:                            136   BIC:                             731.7
# Df Model:                                 27
# Covariance Type:                   nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        11.8011      0.858     13.754      0.000      10.104      13.498
# C(Year)[T.2010]                  -1.1563      0.722     -1.601      0.112      -2.585       0.272
# C(Year)[T.2011]                  -3.2081      0.722     -4.441      0.000      -4.637      -1.779
# C(Year)[T.2012]                  -3.1409      0.711     -4.419      0.000      -4.547      -1.735
# C(Year)[T.2013]                  -4.0577      0.711     -5.709      0.000      -5.463      -2.652
# C(Year)[T.2014]                  -4.9641      0.711     -6.984      0.000      -6.370      -3.558
# C(Year)[T.2015]                  -5.3340      0.717     -7.442      0.000      -6.751      -3.917
# C(Year)[T.2016]                  -6.0622      0.717     -8.458      0.000      -7.480      -4.645
# C(Year)[T.2017]                  -6.2764      0.710     -8.845      0.000      -7.680      -4.873
# C(Year)[T.2018]                  -0.9700      0.425     -2.283      0.024      -1.810      -0.130
# C(Year)[T.2019]                  -0.9037      0.425     -2.127      0.035      -1.744      -0.064
# C(Year)[T.2020]                  -1.3370      0.425     -3.147      0.002      -2.177      -0.497
# C(Year)[T.2021]                  -0.8927      0.425     -2.102      0.037      -1.733      -0.053
# C(Year)[T.2022]                  -1.4058      0.725     -1.938      0.055      -2.840       0.028
# C(Country)[T.Bosnia]             -0.7988      0.752     -1.062      0.290      -2.287       0.689
# C(Country)[T.Bulgaria]            1.0931      0.425      2.574      0.011       0.253       1.933
# C(Country)[T.Czechia]            -3.7480      0.746     -5.022      0.000      -5.224      -2.272
# C(Country)[T.Estonia]            -1.4823      0.425     -3.491      0.001      -2.322      -0.643
# C(Country)[T.Georgia]             5.4648      0.735      7.438      0.000       4.012       6.918
# C(Country)[T.Hungary]             0.9779      0.441      2.216      0.028       0.105       1.851
# C(Country)[T.Latvia]              0.4562      0.425      1.074      0.285      -0.384       1.296
# C(Country)[T.Lithuania]          -1.0277      0.484     -2.121      0.036      -1.986      -0.070
# C(Country)[T.North_Macedonia] -1.175e-17    1.1e-16     -0.107      0.915    -2.3e-16    2.06e-16
# C(Country)[T.Poland]             -0.8708      0.425     -2.051      0.042      -1.711      -0.031
# C(Country)[T.Romania]             2.8638      0.425      6.744      0.000       2.024       3.704
# C(Country)[T.Serbia]             -0.4257      0.873     -0.487      0.627      -2.153       1.301
# C(Country)[T.Slovakia]           -2.1854      0.425     -5.146      0.000      -3.025      -1.346
# C(Country)[T.Slovenia]           -1.4208      0.425     -3.346      0.001      -2.261      -0.581
# C(Country)[T.Turkey]           -1.27e-16   2.63e-17     -4.835      0.000   -1.79e-16   -7.51e-17
# C(Country)[T.Ukraine]          2.587e-16   9.86e-17      2.625      0.010    6.38e-17    4.54e-16
# treated                          -1.5960      0.613     -2.604      0.010      -2.808      -0.384
# post_intervention                -5.5093      0.611     -9.011      0.000      -6.718      -4.300
# treated_intervention             -0.1240      0.598     -0.207      0.836      -1.307       1.059
# ==============================================================================
# Omnibus:                       52.919   Durbin-Watson:                   0.802
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              195.332
# Skew:                           1.184   Prob(JB):                     3.84e-43
# Kurtosis:                       7.794   Cond. No.                     4.81e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.36e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
formula = 'Interest_rate_up_to_1_mln ~ treated + post_intervention + treated_intervention + C(Year) + C(Country) +  + Population_Growth__Percent + GDP_Per_Capita__Dollar + Real_Private_Consumption_Growth__Percent + Real_Government_Consumption_Growth__Percent + Real_Gross_Fixed_Investment_Growth__Percent + Industrial_Production_Growth__Percent'
model = smf.ols(formula, data=cleaned_data).fit()
print(model.summary())
# Out:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Interest_rate_up_to_1_mln   R-squared:                       0.958
# Model:                                   OLS   Adj. R-squared:                  0.914
# Method:                        Least Squares   F-statistic:                     21.89
# Date:                       Mon, 20 May 2024   Prob (F-statistic):           9.20e-11
# Time:                               15:51:23   Log-Likelihood:                -25.393
# No. Observations:                         48   AIC:                             100.8
# Df Residuals:                             23   BIC:                             147.6
# Df Model:                                 24
# Covariance Type:                   nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       7.8473      1.203      6.521      0.000       5.358      10.337
# C(Year)[T.2010]                                 0.1776      1.436      0.124      0.903      -2.792       3.147
# C(Year)[T.2011]                                -1.4375      1.431     -1.005      0.326      -4.397       1.522
# C(Year)[T.2012]                                -1.1747      1.223     -0.961      0.347      -3.705       1.355
# C(Year)[T.2013]                                -1.1522      1.143     -1.008      0.324      -3.517       1.213
# C(Year)[T.2014]                                -0.6844      1.268     -0.540      0.594      -3.307       1.938
# C(Year)[T.2015]                                 0.6145      1.260      0.488      0.630      -1.993       3.222
# C(Year)[T.2016]                                -0.7166      1.141     -0.628      0.536      -3.078       1.644
# C(Year)[T.2017]                                -1.5921      1.275     -1.248      0.224      -4.230       1.046
# C(Year)[T.2018]                                -0.2254      0.422     -0.534      0.598      -1.098       0.647
# C(Year)[T.2019]                                 0.1218      0.336      0.363      0.720      -0.573       0.817
# C(Year)[T.2020]                                -1.4794      0.530     -2.792      0.010      -2.575      -0.383
# C(Year)[T.2021]                                 0.3261      0.880      0.371      0.714      -1.494       2.146
# C(Year)[T.2022]                             -1.924e-14   1.25e-14     -1.540      0.137   -4.51e-14     6.6e-15
# C(Country)[T.Bosnia]                        -2.528e-14   1.32e-14     -1.915      0.068   -5.26e-14    2.03e-15
# C(Country)[T.Bulgaria]                       1.008e-14   5.32e-15      1.894      0.071   -9.31e-16    2.11e-14
# C(Country)[T.Czechia]                         -11.3149      2.629     -4.303      0.000     -16.754      -5.876
# C(Country)[T.Estonia]                          -1.8308      0.739     -2.477      0.021      -3.360      -0.302
# C(Country)[T.Georgia]                           3.4964      0.770      4.541      0.000       1.904       5.089
# C(Country)[T.Hungary]                       -1.598e-14   7.39e-15     -2.163      0.041   -3.13e-14   -6.95e-16
# C(Country)[T.Latvia]                        -1.238e-15   1.39e-15     -0.893      0.381   -4.11e-15    1.63e-15
# C(Country)[T.Lithuania]                     -2.955e-17   1.46e-15     -0.020      0.984   -3.06e-15       3e-15
# C(Country)[T.North_Macedonia]               -3.051e-15   2.23e-15     -1.371      0.184   -7.66e-15    1.55e-15
# C(Country)[T.Poland]                        -5.416e-15   4.24e-15     -1.276      0.215   -1.42e-14    3.36e-15
# C(Country)[T.Romania]                                0          0        nan        nan           0           0
# C(Country)[T.Serbia]                                 0          0        nan        nan           0           0
# C(Country)[T.Slovakia]                         -2.0158      0.302     -6.686      0.000      -2.640      -1.392
# C(Country)[T.Slovenia]                         -3.8065      1.119     -3.400      0.002      -6.122      -1.491
# C(Country)[T.Turkey]                                 0          0        nan        nan           0           0
# C(Country)[T.Ukraine]                                0          0        nan        nan           0           0
# treated                                        -7.6531      2.015     -3.798      0.001     -11.822      -3.484
# post_intervention                              -1.2568      1.051     -1.196      0.244      -3.430       0.917
# treated_intervention                           -1.4410      0.428     -3.368      0.003      -2.326      -0.556
# Population_Growth__Percent                     -0.2210      1.223     -0.181      0.858      -2.752       2.310
# GDP_Per_Capita__Dollar                          0.0004      0.000      2.386      0.026     5.3e-05       0.001
# Real_Private_Consumption_Growth__Percent       -0.1069      0.051     -2.102      0.047      -0.212      -0.002
# Real_Government_Consumption_Growth__Percent    -0.2039      0.067     -3.034      0.006      -0.343      -0.065
# Real_Gross_Fixed_Investment_Growth__Percent    -0.0286      0.021     -1.366      0.185      -0.072       0.015
# Industrial_Production_Growth__Percent          -0.0335      0.059     -0.571      0.574      -0.155       0.088
# ==============================================================================
# Omnibus:                        2.840   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.242   Jarque-Bera (JB):                2.577
# Skew:                           0.558   Prob(JB):                        0.276
# Kurtosis:                       2.787   Cond. No.                     1.04e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.88e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
